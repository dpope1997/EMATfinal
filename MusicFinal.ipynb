# %% [markdown]
# ## "Personal music likes vs. country popularity" report.
#
# ![giphy.gif](attachment:giphy.gif)
#
# #### by Daniel Popescu

# %% [markdown]
# #### 1. Overview
#
# How does some of the music in one of my playlists compare to what's popular in the country based on danceability?
#
# The purpose of this report is to compare personal music that I like to what's popular in the country.

# %%
import requests
import base64
import six
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy

# %% [markdown]
# #### First, we begin by inputing ouur spotify keys which are used to pull the data from the Spotify API.

# %%
tokens = pd.read_csv('Spotify_Keys.txt', sep = '\t', header = None).T
tokens.columns = tokens.iloc[0]
tokens = tokens[1:]
#tokens.Client_Secret[1]

# %% [markdown]
# #### Second, we insert the code for all the tools that we will be using through our project. These are entered in order to help pull said data along with the tokens for it.

# %%
def start_session_headers(client_id, client_secret):
    client_cred = base64.b64encode(six.text_type(client_id + ":" + client_secret).encode("ascii"))
    headers = {"Authorization": "Basic %s" % client_cred.decode("ascii")}
    return headers

#print(start_session_headers(tokens.Client_ID[1], tokens.Client_Secret[1]))

# %%
def connect_to_client_cred(url, headers):
    payload = {'grant_type' : 'client_credentials'}
    response = requests.request("POST", url, headers = headers, data = payload)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def get_access_token():
    #Uses the Client Credentials flow, no access to endpoints with user data
    url = "https://accounts.spotify.com/api/token"
    header = start_session_headers(tokens.Client_ID[1], tokens.Client_Secret[1])
    json_response = connect_to_client_cred(url, header)

    #return json.dumps(json_response, indent = 4, sort_keys = True)
    return json_response

# %%
session_token = get_access_token()
# Out:
# 200

# %%
#session_token

# %%
#session_token['access_token']

# %%
def create_header(session_token):
    headers = {"Authorization": "Bearer {}".format(session_token)}
    return headers

#create_header(session_token['access_token'])

# %%
def connect_to_endpoint(url, headers):
    response =requests.request("GET", url, headers = headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %% [markdown]
# #### The track_audio_features will be used to track each feature for the music in the albums and playlists.

# %%
def track_audio_features(id):
    url = 'https://api.spotify.com/v1/audio-features/{}'.format(id)
    header = create_header(session_token['access_token'])
    json_response = connect_to_endpoint(url, header)
    return json_response

# %% [markdown]
# #### Get_an_album will be used to pull the data for an album from Spotify.

# %%
def get_an_album(id):
    url = 'https://api.spotify.com/v1/albums/{}'.format(id)
    header = create_header(session_token['access_token'])
    json_response = connect_to_endpoint(url, header)
    return json_response

# %% [markdown]
# #### Get_a_playlist will be used to pull the data for a playlist from Spotify.

# %%
def get_a_playlist(id):
    url = 'https://api.spotify.com/v1/playlists/{}'.format(id)
    header = create_header(session_token['access_token'])
    json_response = connect_to_endpoint(url, header)
    return json_response

# %% [markdown]
# ## Now we start entering the codes for each album that we want to use for this report as well as the playlist we want it to compare it with. For this I have chosen some of the albums that I like the most.

# %% [markdown]
# ### GLASS ANIMALS - How To be A Human Being

# %%
album = get_an_album('6qb9MDR0lfsN9a2pw77uJy')
# Out:
# 200

# %%
#album

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '32zkKx35Et6A515oZKxDkD'

# %%
glass_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#audio_features

# %%
glass_features_df = pd.DataFrame(glass_features)
glass_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.699   0.670    1    -6.219     1       0.0347        0.0147
# 1         0.648   0.718    9    -7.765     0       0.0298        0.1290
# 2         0.742   0.289    5    -7.833     0       0.1150        0.5430
# 3         0.698   0.664    7    -7.828     1       0.0778        0.1210
# 4         0.460   0.314    6   -10.158     0       0.0267        0.6990
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.220000     0.356    0.556  111.988  audio_features
# 1          0.001560     0.112    0.785   96.017  audio_features
# 2          0.000046     0.228    0.710  147.986  audio_features
# 3          0.001310     0.331    0.623   96.001  audio_features
# 4          0.000004     0.122    0.216   90.014  audio_features
#
#                        id                                   uri  \
# 0  32zkKx35Et6A515oZKxDkD  spotify:track:32zkKx35Et6A515oZKxDkD
# 1  1LPGwuFgIzbJoShfDdw7MY  spotify:track:1LPGwuFgIzbJoShfDdw7MY
# 2  4vcoNCrTtunmJ9q8srpVly  spotify:track:4vcoNCrTtunmJ9q8srpVly
# 3  5C5gvDZsl6d8bh89URfKHr  spotify:track:5C5gvDZsl6d8bh89URfKHr
# 4  5o4znEHwozOHIgHoWAllnr  spotify:track:5o4znEHwozOHIgHoWAllnr
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/32zkKx35Et6A...
# 1  https://api.spotify.com/v1/tracks/1LPGwuFgIzbJ...
# 2  https://api.spotify.com/v1/tracks/4vcoNCrTtunm...
# 3  https://api.spotify.com/v1/tracks/5C5gvDZsl6d8...
# 4  https://api.spotify.com/v1/tracks/5o4znEHwozOH...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/32zk...       281407
# 1  https://api.spotify.com/v1/audio-analysis/1LPG...       230693
# 2  https://api.spotify.com/v1/audio-analysis/4vco...       243509
# 3  https://api.spotify.com/v1/audio-analysis/5C5g...       253831
# 4  https://api.spotify.com/v1/audio-analysis/5o4z...       266747
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = glass_features_df['danceability'].keys()
vals = glass_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : GLASS ANIMALS - How To be A Human Being")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(glass_features_df['danceability'])
# Out:
# (array([1., 0., 1., 1., 1., 1., 1., 2., 1., 2.]),
#  array([0.46  , 0.4936, 0.5272, 0.5608, 0.5944, 0.628 , 0.6616, 0.6952,
#         0.7288, 0.7624, 0.796 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### JOJI - BALLADS1

# %%
album = get_an_album('34GQP3dILpyCN018y2k61L')
# Out:
# 200

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '5aqu5xhPqoOWqF71PkfgM8'

# %%
joji_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
joji_features_df = pd.DataFrame(joji_features)
joji_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.787   0.312    7   -12.401     1       0.0383         0.895
# 1         0.515   0.479    3    -7.458     1       0.0261         0.544
# 2         0.646   0.648    3    -8.602     1       0.0372         0.710
# 3         0.305   0.715    7    -7.540     1       0.0554         0.105
# 4         0.900   0.316    9    -8.797     1       0.3320         0.684
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.02240    0.1150    0.425  119.899  audio_features
# 1           0.00598    0.1910    0.284   88.964  audio_features
# 2           0.00316    0.1080    0.466   75.004  audio_features
# 3           0.04950    0.0906    0.290   82.977  audio_features
# 4           0.07710    0.0853    0.844  129.914  audio_features
#
#                        id                                   uri  \
# 0  5aqu5xhPqoOWqF71PkfgM8  spotify:track:5aqu5xhPqoOWqF71PkfgM8
# 1  0rKtyWc8bvkriBthvHKY8d  spotify:track:0rKtyWc8bvkriBthvHKY8d
# 2  1DMEzmAoQIikcL52psptQL  spotify:track:1DMEzmAoQIikcL52psptQL
# 3  0Y9D1Bc4fAkeZnVsGKdij6  spotify:track:0Y9D1Bc4fAkeZnVsGKdij6
# 4  39oeKRgsLeynDIbWuXyA47  spotify:track:39oeKRgsLeynDIbWuXyA47
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5aqu5xhPqoOW...
# 1  https://api.spotify.com/v1/tracks/0rKtyWc8bvkr...
# 2  https://api.spotify.com/v1/tracks/1DMEzmAoQIik...
# 3  https://api.spotify.com/v1/tracks/0Y9D1Bc4fAke...
# 4  https://api.spotify.com/v1/tracks/39oeKRgsLeyn...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5aqu...       128888
# 1  https://api.spotify.com/v1/audio-analysis/0rKt...       209274
# 2  https://api.spotify.com/v1/audio-analysis/1DME...       179423
# 3  https://api.spotify.com/v1/audio-analysis/0Y9D...       251015
# 4  https://api.spotify.com/v1/audio-analysis/39oe...       107077
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = joji_features_df['danceability'].keys()
vals = joji_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : JOJI - BALLADS1")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(joji_features_df['danceability'])
# Out:
# (array([1., 2., 1., 1., 0., 2., 2., 0., 2., 1.]),
#  array([0.305 , 0.3645, 0.424 , 0.4835, 0.543 , 0.6025, 0.662 , 0.7215,
#         0.781 , 0.8405, 0.9   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### BILLIE EILISH - WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?

# %%
album = get_an_album('0S0KGZnfBGSIssfF54WSJh')
# Out:
# 200

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '0rQtoQXQfwpDW0c7Fw1NeM'

# %%
billie_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
billie_features_df = pd.DataFrame(billie_features)
billie_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.000   0.278    1   -21.630     1        0.000         0.768
# 1         0.701   0.425    7   -10.965     1        0.375         0.328
# 2         0.521   0.125    9   -17.832     1        0.239         0.751
# 3         0.678   0.533    4   -10.485     1        0.186         0.462
# 4         0.726   0.444    8    -8.922     0        0.372         0.283
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00000     0.669   0.0000    0.000  audio_features
# 1           0.13000     0.100   0.5620  135.128  audio_features
# 2           0.00207     0.265   0.0528  111.554  audio_features
# 3           0.21900     0.139   0.3230  150.455  audio_features
# 4           0.14300     0.177   0.5690  185.044  audio_features
#
#                        id                                   uri  \
# 0  0rQtoQXQfwpDW0c7Fw1NeM  spotify:track:0rQtoQXQfwpDW0c7Fw1NeM
# 1  2Fxmhks0bxGSBdJ92vM42m  spotify:track:2Fxmhks0bxGSBdJ92vM42m
# 2  4QIo4oxwzzafcBWkKjDpXY  spotify:track:4QIo4oxwzzafcBWkKjDpXY
# 3  3XF5xLJHOQQRbWya6hBp7d  spotify:track:3XF5xLJHOQQRbWya6hBp7d
# 4  6IRdLKIyS4p7XNiP8r6rsx  spotify:track:6IRdLKIyS4p7XNiP8r6rsx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0rQtoQXQfwpD...
# 1  https://api.spotify.com/v1/tracks/2Fxmhks0bxGS...
# 2  https://api.spotify.com/v1/tracks/4QIo4oxwzzaf...
# 3  https://api.spotify.com/v1/tracks/3XF5xLJHOQQR...
# 4  https://api.spotify.com/v1/tracks/6IRdLKIyS4p7...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0rQt...        13578
# 1  https://api.spotify.com/v1/audio-analysis/2Fxm...       194088
# 2  https://api.spotify.com/v1/audio-analysis/4QIo...       243725
# 3  https://api.spotify.com/v1/audio-analysis/3XF5...       180953
# 4  https://api.spotify.com/v1/audio-analysis/6IRd...       168840
#
#    time_signature
# 0               0
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = billie_features_df['danceability'].keys()
vals = billie_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : BILLIE EILISH - WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(billie_features_df['danceability'])
# Out:
# (array([1., 1., 0., 2., 1., 1., 0., 4., 0., 4.]),
#  array([0.    , 0.0939, 0.1878, 0.2817, 0.3756, 0.4695, 0.5634, 0.6573,
#         0.7512, 0.8451, 0.939 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### KID CUDI - Man On The Moon: The End Of Day

# %%
album = get_an_album('47y3PbX8oIDCkYAFylCJz0')
# Out:
# 200

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '3Xm9jQDd8my7ui5DUtEHYf'

# %%
kid_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
kid_features_df = pd.DataFrame(kid_features)
kid_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.650   0.417    2   -12.413     0       0.0574         0.286
# 1         0.464   0.754    9    -6.653     0       0.1280         0.465
# 2         0.802   0.742    1    -4.607     1       0.1110         0.265
# 3         0.768   0.449    7    -7.569     0       0.0290         0.518
# 4         0.723   0.452   11    -9.420     0       0.0328         0.308
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000033    0.1040    0.475   98.415  audio_features
# 1          0.000016    0.3700    0.444   86.501  audio_features
# 2          0.000287    0.6300    0.512   95.000  audio_features
# 3          0.000463    0.1360    0.614   79.120  audio_features
# 4          0.006400    0.0923    0.375  125.015  audio_features
#
#                        id                                   uri  \
# 0  3Xm9jQDd8my7ui5DUtEHYf  spotify:track:3Xm9jQDd8my7ui5DUtEHYf
# 1  1cdC9TCqyLwAlsw3fVJaJS  spotify:track:1cdC9TCqyLwAlsw3fVJaJS
# 2  77fcAXl6MsFPtFJG45zTUE  spotify:track:77fcAXl6MsFPtFJG45zTUE
# 3  2EHEQx2avP1fNBLJf5UGYy  spotify:track:2EHEQx2avP1fNBLJf5UGYy
# 4  246SdvVYT3yrZPXU7NSWwy  spotify:track:246SdvVYT3yrZPXU7NSWwy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3Xm9jQDd8my7...
# 1  https://api.spotify.com/v1/tracks/1cdC9TCqyLwA...
# 2  https://api.spotify.com/v1/tracks/77fcAXl6MsFP...
# 3  https://api.spotify.com/v1/tracks/2EHEQx2avP1f...
# 4  https://api.spotify.com/v1/tracks/246SdvVYT3yr...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3Xm9...       199000
# 1  https://api.spotify.com/v1/audio-analysis/1cdC...       235627
# 2  https://api.spotify.com/v1/audio-analysis/77fc...       151333
# 3  https://api.spotify.com/v1/audio-analysis/2EHE...       266307
# 4  https://api.spotify.com/v1/audio-analysis/246S...       261360
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = kid_features_df['danceability'].keys()
vals = kid_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : KID CUDI - Man On The Moon: The End Of Day")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(kid_features_df['danceability'])
# Out:
# (array([1., 0., 1., 2., 2., 4., 2., 1., 1., 1.]),
#  array([0.464 , 0.5106, 0.5572, 0.6038, 0.6504, 0.697 , 0.7436, 0.7902,
#         0.8368, 0.8834, 0.93  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### KID CUDI - Passion, Pain & Demon Slayin'

# %%
album = get_an_album('5bCk3kWAy2JbbTfHqzZCII')
# Out:
# 200

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '0O6jl8Zamz6TGF0nUwMQsF'

# %%
cudi_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
cudi_features_df = pd.DataFrame(cudi_features)
cudi_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.791   0.577    1    -6.555     1       0.0367        0.4980
# 1         0.357   0.377    2   -10.723     1       0.0428        0.6100
# 2         0.595   0.442    7   -11.115     0       0.0289        0.1160
# 3         0.756   0.850    9    -5.885     0       0.0538        0.0559
# 4         0.661   0.596    9    -8.176     0       0.0801        0.0391
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.470000     0.120    0.217  115.070  audio_features
# 1          0.371000     0.110    0.116  165.208  audio_features
# 2          0.770000     0.114    0.134   81.992  audio_features
# 3          0.000809     0.111    0.415  100.005  audio_features
# 4          0.331000     0.943    0.538  154.017  audio_features
#
#                        id                                   uri  \
# 0  0O6jl8Zamz6TGF0nUwMQsF  spotify:track:0O6jl8Zamz6TGF0nUwMQsF
# 1  5cjsgbZ8tZYD4f0LNpApnf  spotify:track:5cjsgbZ8tZYD4f0LNpApnf
# 2  5Tm9At0xeFb0MtlV8uI3eY  spotify:track:5Tm9At0xeFb0MtlV8uI3eY
# 3  5FxVTEpoBress37MmlMhbZ  spotify:track:5FxVTEpoBress37MmlMhbZ
# 4  4HMhDkyOObFngSAz2xeQhK  spotify:track:4HMhDkyOObFngSAz2xeQhK
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0O6jl8Zamz6T...
# 1  https://api.spotify.com/v1/tracks/5cjsgbZ8tZYD...
# 2  https://api.spotify.com/v1/tracks/5Tm9At0xeFb0...
# 3  https://api.spotify.com/v1/tracks/5FxVTEpoBres...
# 4  https://api.spotify.com/v1/tracks/4HMhDkyOObFn...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0O6j...       298240
# 1  https://api.spotify.com/v1/audio-analysis/5cjs...       269227
# 2  https://api.spotify.com/v1/audio-analysis/5Tm9...       327973
# 3  https://api.spotify.com/v1/audio-analysis/5FxV...       257053
# 4  https://api.spotify.com/v1/audio-analysis/4HMh...       250587
#
#    time_signature
# 0               4
# 1               3
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = cudi_features_df['danceability'].keys()
vals = cudi_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : KID CUDI - Passion, Pain & Demon Slayin'")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(cudi_features_df['danceability'])
# Out:
# (array([1., 0., 1., 1., 2., 4., 3., 0., 5., 2.]),
#  array([0.357, 0.403, 0.449, 0.495, 0.541, 0.587, 0.633, 0.679, 0.725,
#         0.771, 0.817]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### TAME IMPALA - Currents

# %%
album = get_an_album('79dL7FLiJFOO0EoehUHQBv')
# Out:
# 200

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '2X485T9Z5Ly0xyaghN73ed'

# %%
impala_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
impala_features_df = pd.DataFrame(impala_features)
impala_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.602   0.881    1    -5.875     0       0.0443      0.004620
# 1         0.536   0.526    0    -9.754     1       0.1810      0.159000
# 2         0.547   0.827    7    -6.036     1       0.0468      0.000296
# 3         0.373   0.609    0    -7.000     1       0.0316      0.108000
# 4         0.424   0.615    9    -6.217     0       0.0325      0.015800
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.026600    0.1110    0.577  125.012  audio_features
# 1          0.847000    0.1280    0.434  167.608  audio_features
# 2          0.101000    0.0858    0.451  119.089  audio_features
# 3          0.000427    0.0755    0.354  179.955  audio_features
# 4          0.000389    0.0844    0.155   77.935  audio_features
#
#                        id                                   uri  \
# 0  2X485T9Z5Ly0xyaghN73ed  spotify:track:2X485T9Z5Ly0xyaghN73ed
# 1  1cCbsojaA6GIT7Y3zuMJ1q  spotify:track:1cCbsojaA6GIT7Y3zuMJ1q
# 2  1UYj8qTWjneZJDVjUMwMub  spotify:track:1UYj8qTWjneZJDVjUMwMub
# 3  0xtIp0lgccN85GfGOekS5L  spotify:track:0xtIp0lgccN85GfGOekS5L
# 4  5M4yti0QxgqJieUYaEXcpw  spotify:track:5M4yti0QxgqJieUYaEXcpw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2X485T9Z5Ly0...
# 1  https://api.spotify.com/v1/tracks/1cCbsojaA6GI...
# 2  https://api.spotify.com/v1/tracks/1UYj8qTWjneZ...
# 3  https://api.spotify.com/v1/tracks/0xtIp0lgccN8...
# 4  https://api.spotify.com/v1/tracks/5M4yti0QxgqJ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2X48...       467587
# 1  https://api.spotify.com/v1/audio-analysis/1cCb...       107533
# 2  https://api.spotify.com/v1/audio-analysis/1UYj...       255413
# 3  https://api.spotify.com/v1/audio-analysis/0xtI...       270680
# 4  https://api.spotify.com/v1/audio-analysis/5M4y...       318591
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = impala_features_df['danceability'].keys()
vals = impala_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : TAME IMPALA - Currents")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(impala_features_df['danceability'])
# Out:
# (array([2., 1., 0., 1., 1., 2., 3., 1., 0., 2.]),
#  array([0.371, 0.4  , 0.429, 0.458, 0.487, 0.516, 0.545, 0.574, 0.603,
#         0.632, 0.661]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### MAC MILLER - Swimming

# %%
album = get_an_album('5wtE5aLX5r7jOosmPhJhhk')
# Out:
# 200

# %%
album.keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'total_tracks', 'tracks', 'type', 'uri'])

# %%
album['tracks']['items'][0]['id']
# Out:
# '01z2fBGB8Hl3Jd3zXe4IXR'

# %%
miller_features = [track_audio_features(x['id']) for x in album['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
miller_features_df = pd.DataFrame(miller_features)
miller_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.272   0.238    2   -12.148     0       0.0349         0.890
# 1         0.690   0.462    8    -8.054     1       0.1300         0.343
# 2         0.759   0.492    1   -10.338     0       0.1200         0.736
# 3         0.599   0.317    1   -11.212     1       0.1740         0.748
# 4         0.520   0.538    1    -8.109     1       0.2060         0.367
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00925     0.275    0.119   83.507  audio_features
# 1           0.00218     0.113    0.325  157.655  audio_features
# 2           0.00989     0.107    0.561  104.974  audio_features
# 3           0.00000     0.111    0.203  148.090  audio_features
# 4           0.00187     0.119    0.177  141.894  audio_features
#
#                        id                                   uri  \
# 0  01z2fBGB8Hl3Jd3zXe4IXR  spotify:track:01z2fBGB8Hl3Jd3zXe4IXR
# 1  5p7GiBZNL1afJJDUrOA6C8  spotify:track:5p7GiBZNL1afJJDUrOA6C8
# 2  2dgrYdgguVZKeCsrVb9XEs  spotify:track:2dgrYdgguVZKeCsrVb9XEs
# 3  0Xcy81PsJCOO6mhLZaQyQ4  spotify:track:0Xcy81PsJCOO6mhLZaQyQ4
# 4  5bJ1DrEM4hNCafcDd1oxHx  spotify:track:5bJ1DrEM4hNCafcDd1oxHx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/01z2fBGB8Hl3...
# 1  https://api.spotify.com/v1/tracks/5p7GiBZNL1af...
# 2  https://api.spotify.com/v1/tracks/2dgrYdgguVZK...
# 3  https://api.spotify.com/v1/tracks/0Xcy81PsJCOO...
# 4  https://api.spotify.com/v1/tracks/5bJ1DrEM4hNC...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/01z2...       161840
# 1  https://api.spotify.com/v1/audio-analysis/5p7G...       245640
# 2  https://api.spotify.com/v1/audio-analysis/2dgr...       288640
# 3  https://api.spotify.com/v1/audio-analysis/0Xcy...       215413
# 4  https://api.spotify.com/v1/audio-analysis/5bJ1...       345133
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Below is a graph visualizing the danceability for this album. Each line below represents the danceability of each song on a scare from 0 to 1.0

# %%
labels = miller_features_df['danceability'].keys()
vals = miller_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in album : MAC MILLER - Swimming")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(miller_features_df['danceability'])
# Out:
# (array([1., 0., 0., 0., 3., 1., 2., 2., 0., 4.]),
#  array([0.272, 0.325, 0.378, 0.431, 0.484, 0.537, 0.59 , 0.643, 0.696,
#         0.749, 0.802]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### PLAYLIST - TOP 50 USA

# %%
playlist = get_a_playlist('37i9dQZEVXbLRQDuF5jeBp')
# Out:
# 200

# %%
type(playlist['tracks']['items'])
# Out:
# list

# %%
playlist['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
type(playlist['tracks']['items'][0]['track'])
# Out:
# dict

# %%
playlist['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
top_features = [track_audio_features(x['track']['id']) for x in playlist['tracks']['items']]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
top_features_df = pd.DataFrame(top_features)
top_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.762   0.701    8    -3.541     1       0.0286        0.2350
# 1         0.789   0.536    6    -6.862     1       0.2420        0.4100
# 2         0.584   0.859    8    -5.616     1       0.1210        0.0144
# 3         0.604   0.668    1    -3.525     1       0.1150        0.1100
# 4         0.610   0.508    8    -6.682     0       0.1520        0.2970
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000158     0.123    0.742  110.968  audio_features
# 1          0.000000     0.129    0.437   81.039  audio_features
# 2          0.000000     0.847    0.369   77.005  audio_features
# 3          0.000000     0.407    0.114  100.854  audio_features
# 4          0.000000     0.384    0.758  178.818  audio_features
#
#                        id                                   uri  \
# 0  748mdHapucXQri7IAO8yFK  spotify:track:748mdHapucXQri7IAO8yFK
# 1  43PGPuHIlVOc04jrZVh9L6  spotify:track:43PGPuHIlVOc04jrZVh9L6
# 2  2BITQ360Knh6qNAOqR7Dyq  spotify:track:2BITQ360Knh6qNAOqR7Dyq
# 3  2gyYjQWXKxemhAyMPgctIx  spotify:track:2gyYjQWXKxemhAyMPgctIx
# 4  67BtfxlNbhBmCDR2L2l8qd  spotify:track:67BtfxlNbhBmCDR2L2l8qd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/748mdHapucXQ...
# 1  https://api.spotify.com/v1/tracks/43PGPuHIlVOc...
# 2  https://api.spotify.com/v1/tracks/2BITQ360Knh6...
# 3  https://api.spotify.com/v1/tracks/2gyYjQWXKxem...
# 4  https://api.spotify.com/v1/tracks/67BtfxlNbhBm...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/748m...       208867
# 1  https://api.spotify.com/v1/audio-analysis/43PG...       165926
# 2  https://api.spotify.com/v1/audio-analysis/2BIT...       236883
# 3  https://api.spotify.com/v1/audio-analysis/2gyY...       131413
# 4  https://api.spotify.com/v1/audio-analysis/67Bt...       137876
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               3
# 4               4

# %% [markdown]
# ### This following graph is meant to show the danceability for the Top 50 playlist.

# %%
labels = top_features_df['danceability'].keys()
vals = top_features_df['danceability']
width = .75

fig, ax = plt.subplots(figsize=(10,10), dpi = 80, facecolor = 'w', edgecolor = 'k')
ax.bar(labels,vals)
ax.set_ylabel('danceability')
plt.xticks(rotation=90, fontsize = 'small')
plt.legend(['Songs'])
ax.set_title("Danceability of the songs in TOP 50 playlist")
plt.show()

# %% [markdown]
# This second following plot uses the data from above, but instead it combines all the songs under their respective danceability.
#
# This means that the Y-axis in this case is the number of songs and the X-axis is the danceability rating for those songs.

# %%
plt.hist(top_features_df['danceability'])
# Out:
# (array([4., 3., 0., 8., 7., 5., 6., 7., 4., 6.]),
#  array([0.422 , 0.4705, 0.519 , 0.5675, 0.616 , 0.6645, 0.713 , 0.7615,
#         0.81  , 0.8585, 0.907 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Next I am trying to compare both plots and see how the data matches danceability wise if at all.
#
# First I will be putting each plt.hist() from all the albums and the playlist on top of each other to compare the danceability for all of them.

# %%
fig, ax1 = plt.subplots(1,1)

ax1.hist(top_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(glass_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(joji_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(billie_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(kid_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(cudi_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(impala_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
ax1.hist(miller_features_df['danceability'], alpha = 0.9, histtype = 'barstacked')
plt.legend(['TOP 50', 'Glass Animals', 'Joji', 'Billie', 'Kid', 'Cudi', 'Impala', 'Miller'])
plt.show()

# %% [markdown]
# From this plot, having all of the albums and the playlist layed out on each other, we can tell that the overall danceability for the TOP 50 playlist is definitely way higher than any album listed.

# %% [markdown]
# ### We are now going to turn it into a T-test to get our averages for each album and see how they compare to the TOP 50 playlist.

# %% [markdown]
# With the below commands we will be taking the data for the TOP 50 playlist and compare it to the data for each individual album.

# %% [markdown]
# ##### Glass animals - How to be a human

# %%
stats.ttest_ind(top_features_df['danceability'], glass_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=0.8098843454133402, pvalue=0.4212611350509906)

# %% [markdown]
# ##### Joji - Ballads1

# %%
stats.ttest_ind(top_features_df['danceability'], joji_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=1.9175735735839992, pvalue=0.05992903019217435)

# %% [markdown]
# ##### BILLIE EILISH - WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?

# %%
stats.ttest_ind(top_features_df['danceability'], billie_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=2.0275153486966606, pvalue=0.04691371988437877)

# %% [markdown]
# ##### KID CUDI - Man On The Moon: The End Of Day

# %%
stats.ttest_ind(top_features_df['danceability'], kid_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=-0.3883346195740347, pvalue=0.6990776328214419)

# %% [markdown]
# ##### KID CUDI - Passion, Pain & Demon Slayin'

# %%
stats.ttest_ind(top_features_df['danceability'], cudi_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=1.4324207725916902, pvalue=0.15667271531287946)

# %% [markdown]
# ##### TAME IMPALA - Currents

# %%
stats.ttest_ind(top_features_df['danceability'], impala_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=4.437125545722488, pvalue=3.885094812055302e-05)

# %% [markdown]
# ##### MAC MILLER - Swimming

# %%
stats.ttest_ind(top_features_df['danceability'], miller_features_df['danceability'])
# Out:
# Ttest_indResult(statistic=1.6149312125207929, pvalue=0.11148680304615421)

# %% [markdown]
# Now that all of that is done we see that the tests we have run on each album gave as an individual pvalue. But what is this pvalue that we have received? Each one differs and some are smaller or bigger than others.

# %% [markdown]
# The pvalues here are the calculated probabilities for each album. It shows the probability of that album and its chances of being on the same level for danceability as the TOP50 album.
#
# The first part, the statistic number is the T number. The closer that number is to 0 the more likely it is that there isn't a significant difference between the album and the TOP 50 playlist. This means that if the statistic number is close to 0, that specific album and the playlist are not very different when it comes to danceability rather they are very similar.
#
# From what we've gathered above. We can tell that the Glass animals - How to be a human and KID CUDI - Man On The Moon: The End Of Day albums are the closest ones to the TOP-50 playlist when it comes to danceability.
#
# ##### Glass animals - How to be a human = statistic=0.8098843454133402, pvalue=0.4212611350509906
#
# ##### KID CUDI - Man On The Moon: The End Of Day = statistic=-0.3883346195740347, pvalue=0.6990776328214419
#
# However, there is one single album that is very, very far away from being close to the TOP-50 for danceability.
#
# ##### TAME IMPALA - Currents = statistic=4.437125545722488, pvalue=3.885094812055302e-05
#
# The Tame Impala is far, far away. We can tell this just by looking at it's statistic number which is 4.43~. The farther away the number is from 0, the bigger the chance is that there is a significant difference between the album and the playlist. This makes sense though, Tame Impala isn't exactly something you'd get up and dance to, but rather something you'd sit down, chill, and listen to on relaxing night.

# %% [markdown]
# ### Conclusion.
#
# ![tumblr_o51ye7S6S01v1ndxmo1_540.gif](attachment:tumblr_o51ye7S6S01v1ndxmo1_540.gif)

# %% [markdown]
# From the data that we have acquired and tested above we can tell that not many of the albums are on the same level with the TOP-50 album when it comes to danceability.
#
# Out of 7 albums, only 2 comes clsoe to being the same danceability-wise.
#
# The two albums are:
#
# Glass animals - How to be a human being
#
# KID CUDI - Man On THe Moon: The End of Day
#
# What I am gathering from this analysis is that my albums don't tend to have a high danceability. They are not something that you'd exactly get up a dance to which makes sense. If you've ever listened to something like Tame Impala for example, you'd easily be able to tell that it's the type of music you don't dance to but rather relax to.
#
# However, in a way it does make sense that the Glass Animals and Kid Cudi albums are the highest ones in the list. The ones that most closely match the danceability of the TOP-50 playlist. This is because these two playlists are something that you could possibly play at a party and have people enjoy and dance to. They are definitely up there when it comes to entertainment and getting people moving on the dance floor.
#
# In the end my music didn't exactly match what is popular in the country at the moment. I guess this isn't too shocking because I tend to like this that are somewhat popular, but not on a national scale where it would make the charts. None of my music tastes are big like Drake or any huge artists like that, that make the charts all the time.

# %% [markdown]
# ### Limitations, Alternative Approaches & Next Steps.

# %% [markdown]
# A question that has risen from this analysis for me is what makes the songs in TOP-50 so popular. Is it the genre, is it the artist, is it the way the spotify algorithm works? Maybe some of these songs are pushed on users which in return makes them be listen to and create more popularity for each one of them.
#
# Additionally, while the analysis did answer my question and I was able to compare the danceability for my albums and the TOP-50, something I am thinking I could've done differently (an alternative approach) would be to compare genres at the same time. Genres can take a part in what's popular and the genre of a song/album can often influence its danceability as well. A song or album can be very good, but at the same time its danceability can be very low if the genre, for example, is something like classical bethoven music. I definitely believe that the genres can be a way of testing the danceability of an album as well and that would be a good alternative approach to this analysis.
#
# A limitation that arises from this analysis is not being able to see that many items for the data. I was only really able to see things such as danceability, loudness, speechness and so on. Something that could've been useful would've maybe been dates when the music was released and try to work that in somehow as well.
